# %%
path = "./data/tweet.js"

with open(path, "r") as f:
    raw_text = f.read()

# %%
raw_text = raw_text.replace("window.YTD.tweet.part0 = ", "")

# %%
import json
from pprint import pprint
from dateutil.parser import parse

data = json.loads(raw_text)

# %%
for tweet in data:
    tweet = tweet['tweet']
    id = tweet["id_str"]
    date = str(parse(tweet['created_at'])).split("+")[0]
    text = tweet["full_text"]
    pprint(tweet)
    print()
    print()
# Out:
# {'created_at': 'Wed Apr 15 19:21:33 +0000 2020',
#  'display_text_range': ['0', '29'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '892732157294030848',
#                                  'id_str': '892732157294030848',
#                                  'indices': ['0', '10'],
#                                  'name': 'tkasasagi🐻 cookie bear',
#                                  'screen_name': 'tkasasagi'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '@tkasasagi You looks so good!',
#  'id': '1250504555005083649',
#  'id_str': '1250504555005083649',
#  'in_reply_to_screen_name': 'tkasasagi',
#  'in_reply_to_status_id': '1250427941567094786',
#  'in_reply_to_status_id_str': '1250427941567094786',
#  'in_reply_to_user_id': '892732157294030848',
#  'in_reply_to_user_id_str': '892732157294030848',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Wed Apr 15 06:40:29 +0000 2020',
#  'display_text_range': ['0', '122'],
#  'entities': {'hashtags': [{'indices': ['91', '98'], 'text': 'Github'}],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/BillGates/stat…',
#                         'expanded_url': 'https://twitter.com/BillGates/status/1250292126643941376',
#                         'indices': ['99', '122'],
#                         'url': 'https://t.co/J78RtD5iaD'}],
#               'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'It makes me doubt weather the GitHub is still a trustable '
#               'platform for private repository. #Github '
#               'https://t.co/J78RtD5iaD',
#  'id': '1250313022888742912',
#  'id_str': '1250313022888742912',
#  'lang': 'en',
#  'possibly_sensitive': False,
#  'retweet_count': '2',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Mon Apr 13 16:44:21 +0000 2020',
#  'display_text_range': ['0', '81'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'reddit.com/r/freelance/co…',
#                         'expanded_url': 'https://www.reddit.com/r/freelance/comments/5wnfu9/my_client_is_asking_me_for_source_codewhat_to_do/',
#                         'indices': ['58', '81'],
#                         'url': 'https://t.co/UIvBXEHNkl'}],
#               'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': "Next time if I do freelance again, I'll make a contract.\n"
#               '\n'
#               'https://t.co/UIvBXEHNkl',
#  'id': '1249740215524065289',
#  'id_str': '1249740215524065289',
#  'lang': 'en',
#  'possibly_sensitive': False,
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Sat Apr 11 11:56:21 +0000 2020',
#  'display_text_range': ['0', '111'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '我享受一个人的生活。\n'
#               '\n'
#               '记得初中时班主任问我这辈子最想干什么，我说我想当鲁宾逊。她当时以为我疯了(有精神病)。\n'
#               '\n'
#               '实际上，就目前来讲，如果鲁宾逊独自拥有一个小岛，一间自制别墅，一台可以上网的电脑。不知道他可以过得多么舒适！',
#  'id': '1248942964640014341',
#  'id_str': '1248942964640014341',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Fri Apr 10 13:47:57 +0000 2020',
#  'display_text_range': ['0', '88'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '1401204486',
#                                  'id_str': '1401204486',
#                                  'indices': ['0', '8'],
#                                  'name': 'Harrison Kinsley🐍',
#                                  'screen_name': 'Sentdex'},
#                                 {'id': '117441415',
#                                  'id_str': '117441415',
#                                  'indices': ['9', '24'],
#                                  'name': 'Daniel Kukieła',
#                                  'screen_name': 'daniel_kukiela'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': "@Sentdex @daniel_kukiela Wow, it's amazing to see that you are "
#               'starting to write a book.',
#  'id': '1248608660525211648',
#  'id_str': '1248608660525211648',
#  'in_reply_to_screen_name': 'Sentdex',
#  'in_reply_to_status_id': '1248594664661409793',
#  'in_reply_to_status_id_str': '1248594664661409793',
#  'in_reply_to_user_id': '1401204486',
#  'in_reply_to_user_id_str': '1401204486',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Thu Apr 09 19:17:50 +0000 2020',
#  'display_text_range': ['0', '210'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '我们可以做游戏，可以做网页，可以做用 IDE 做 Native App，但这些东西是个人都可以做。\n'
#               '所以我不想做。\n'
#               '\n'
#               'We could make games, we could make websites, we could make '
#               'Native Apps by using specific IDE.\n'
#               "But I don't wanna do that because everyone could do that.",
#  'id': '1248329291114446849',
#  'id_str': '1248329291114446849',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Thu Apr 09 13:29:19 +0000 2020',
#  'display_text_range': ['0', '214'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': "与效率说不矛盾，减少重复劳动，有更多时间享受生活，that's a pleasure.\n"
#               '\n'
#               'This has no combat with the efficiency theory, because when you '
#               'are efficiency, you do less repeated work. Then with the time '
#               "you've saved, you can enjoy your life more.",
#  'id': '1248241582098264064',
#  'id_str': '1248241582098264064',
#  'in_reply_to_screen_name': 'yingshaoxo',
#  'in_reply_to_status_id': '1248240572625805320',
#  'in_reply_to_status_id_str': '1248240572625805320',
#  'in_reply_to_user_id': '4512527954',
#  'in_reply_to_user_id_str': '4512527954',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Thu Apr 09 13:25:18 +0000 2020',
#  'display_text_range': ['0', '231'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'You success level depends on how much pleasures that you can '
#               'give to others.\n'
#               '\n'
#               'Like Twitter, YouTube, Telegram, they gave me pleasures, so '
#               'they are success.\n'
#               '\n'
#               '你的成功取决于你取悦别人的水平。\n'
#               '\n'
#               '感觉有点道理啊，因为一个好的服务就是要让人感到愉悦，比如 Twitter, YouTube, Telegram.',
#  'id': '1248240572625805320',
#  'id_str': '1248240572625805320',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Wed Apr 08 17:15:13 +0000 2020',
#  'display_text_range': ['0', '135'],
#  'entities': {'hashtags': [{'indices': ['124', '135'], 'text': 'OpenSource'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'Later in my life, if I ever do open source again, I will use '
#               '`GNU GPL` as my license.\n'
#               '\n'
#               'GNU GPL: GNU General Public License. #OpenSource',
#  'id': '1247936047033405440',
#  'id_str': '1247936047033405440',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web '
#            'App</a>',
#  'truncated': False}
#
#
# {'created_at': 'Wed Apr 08 15:25:15 +0000 2020',
#  'display_text_range': ['0', '31'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': "It's said by Douglas MacArthur.",
#  'id': '1247908372822679553',
#  'id_str': '1247908372822679553',
#  'in_reply_to_screen_name': 'yingshaoxo',
#  'in_reply_to_status_id': '1247907794642063361',
#  'in_reply_to_status_id_str': '1247907794642063361',
#  'in_reply_to_user_id': '4512527954',
#  'in_reply_to_user_id_str': '4512527954',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Wed Apr 08 15:22:57 +0000 2020',
#  'display_text_range': ['0', '277'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'People grow old only by deserting their ideals. \n'
#               '\n'
#               'Years may wrinkle the skin, but to give up interest wrinkles '
#               'the soul.\n'
#               '\n'
#               'You are as young as your faith, as old as your doubt; as young '
#               'as your self-confidence, as old as your fear; as young as your '
#               'hope, as old as your despair.',
#  'id': '1247907794642063361',
#  'id_str': '1247907794642063361',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web '
#            'App</a>',
#  'truncated': False}
#
#
# {'created_at': 'Tue Apr 07 18:27:39 +0000 2020',
#  'display_text_range': ['0', '105'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'The world only got two different people eventually: 0 and 1 .\n'
#               '\n'
#               "This is a basic fact that we can't change.",
#  'id': '1247591887353020416',
#  'id_str': '1247591887353020416',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Mon Apr 06 23:20:54 +0000 2020',
#  'display_text_range': ['0', '63'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '799306946947923968',
#                                  'id_str': '799306946947923968',
#                                  'indices': ['0', '16'],
#                                  'name': '一只雪乃',
#                                  'screen_name': 'NakashimaYukino'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '@NakashimaYukino 绝对得闭嘴，多说还惹一身麻烦。\n'
#               '\n'
#               '这里可不是自由的天地。并且大多数人的思想和你我完全不一样。',
#  'id': '1247303299084271619',
#  'id_str': '1247303299084271619',
#  'in_reply_to_screen_name': 'NakashimaYukino',
#  'in_reply_to_status_id': '1247284386568916994',
#  'in_reply_to_status_id_str': '1247284386568916994',
#  'in_reply_to_user_id': '799306946947923968',
#  'in_reply_to_user_id_str': '799306946947923968',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Sun Apr 05 13:12:01 +0000 2020',
#  'display_text_range': ['0', '192'],
#  'entities': {'hashtags': [{'indices': ['186', '192'], 'text': 'Bazel'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': []},
#  'favorite_count': '1',
#  'favorited': False,
#  'full_text': 'I learn Bazel to help me reduce the hating to other programming '
#               "languages that I don't know. Bazel would always remind me, they "
#               "aren't enemies, I can work with them commonly and easily. "
#               '#Bazel',
#  'id': '1246787677925638145',
#  'id_str': '1246787677925638145',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web '
#            'App</a>',
#  'truncated': False}
#
#
# {'created_at': 'Fri Apr 03 17:30:07 +0000 2020',
#  'display_text_range': ['0', '136'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'They want me to be a fool, I disagree, I did the opposite. I '
#               "got the knowledge that they don't want me to get.\n"
#               '\n'
#               'I should be proud of me.',
#  'id': '1246127854468739072',
#  'id_str': '1246127854468739072',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Fri Apr 03 06:40:42 +0000 2020',
#  'display_text_range': ['0', '42'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '5709522',
#                                  'id_str': '5709522',
#                                  'indices': ['0', '7'],
#                                  'name': 'Michael Anti',
#                                  'screen_name': 'mranti'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '@mranti This is what called cold war, bro.',
#  'id': '1245964426936602624',
#  'id_str': '1245964426936602624',
#  'in_reply_to_screen_name': 'mranti',
#  'in_reply_to_status_id': '1245870707847782400',
#  'in_reply_to_status_id_str': '1245870707847782400',
#  'in_reply_to_user_id': '5709522',
#  'in_reply_to_user_id_str': '5709522',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Tue Mar 31 16:22:27 +0000 2020',
#  'display_text_range': ['0', '130'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '如果不承认自己的愚蠢，恐怕永远也无法取得进步。\n'
#               '\n'
#               'If you want to be good at something, the first thing for you to '
#               'do is to admit that you are stupid at it.',
#  'id': '1245023663109349376',
#  'id_str': '1245023663109349376',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Tue Mar 31 09:30:32 +0000 2020',
#  'display_text_range': ['0', '244'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'Sorry to say this, but developers is indeed at the bottom of '
#               'the game.\n'
#               '\n'
#               'They work so hard every day but eventually most profits was '
#               'taken by their boss or shareholders.\n'
#               '\n'
#               'To overcome this drawback, you have to be your own CEO when '
#               "it's possible.",
#  'id': '1244920002123165697',
#  'id_str': '1244920002123165697',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Sun Mar 29 03:09:26 +0000 2020',
#  'display_text_range': ['0', '112'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '45635727',
#                                  'id_str': '45635727',
#                                  'indices': ['0', '8'],
#                                  'name': '消极',
#                                  'screen_name': 'cxiaoji'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '@cxiaoji Maybe close-source is a good thing for a company. '
#               '因为谁最先耍流氓不开源，谁就赚很多钱。Like a lot of Chinese company did.',
#  'id': '1244099320602701826',
#  'id_str': '1244099320602701826',
#  'in_reply_to_screen_name': 'cxiaoji',
#  'in_reply_to_status_id': '1243943463042699264',
#  'in_reply_to_status_id_str': '1243943463042699264',
#  'in_reply_to_user_id': '45635727',
#  'in_reply_to_user_id_str': '45635727',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Fri Mar 27 13:39:08 +0000 2020',
#  'display_text_range': ['0', '285'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '2786701',
#                                  'id_str': '2786701',
#                                  'indices': ['0', '12'],
#                                  'name': '月光博客',
#                                  'screen_name': 'williamlong'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '@williamlong Sh_t, that makes stupid guy very happy, because '
#               "they're much safer.\n"
#               '\n'
#               "But for those genius, it's a disaster, they'll lose their "
#               "creativity and getting unhealthy day by day because they're no "
#               'longer getting the fresh air to do what they wanna do, to say '
#               'what they wanna say.',
#  'id': '1243533011800346625',
#  'id_str': '1243533011800346625',
#  'in_reply_to_screen_name': 'williamlong',
#  'in_reply_to_status_id': '1243344321463508993',
#  'in_reply_to_status_id_str': '1243344321463508993',
#  'in_reply_to_user_id': '2786701',
#  'in_reply_to_user_id_str': '2786701',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Fri Mar 27 09:46:11 +0000 2020',
#  'display_text_range': ['0', '199'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '4. self aware: know you are stupid, and you need to continue to '
#               "learn, and you can't master all those stuff except for one "
#               "specific area. You're special only because of what you are "
#               'capable of doing.',
#  'id': '1243474387187073024',
#  'id_str': '1243474387187073024',
#  'in_reply_to_screen_name': 'yingshaoxo',
#  'in_reply_to_status_id': '1243473663933833218',
#  'in_reply_to_status_id_str': '1243473663933833218',
#  'in_reply_to_user_id': '4512527954',
#  'in_reply_to_user_id_str': '4512527954',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Fri Mar 27 09:43:18 +0000 2020',
#  'display_text_range': ['0', '196'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'Core values for a developer\n'
#               '\n'
#               '1. sync: always have a backup for your own data.\n'
#               '2. safe: never let anyone spy on you.\n'
#               '3. resources: never let anyone get  control of what you can '
#               "see, what you can't.",
#  'id': '1243473663933833218',
#  'id_str': '1243473663933833218',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Tue Mar 24 13:43:30 +0000 2020',
#  'display_text_range': ['0', '132'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'Watch TV or Movies in twice speed could indeed increase your '
#               'thinking speed, but it has side consequences: you forgot things '
#               'easily.',
#  'id': '1242446948784910336',
#  'id_str': '1242446948784910336',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Tue Mar 24 03:15:00 +0000 2020',
#  'display_text_range': ['0', '46'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/GoogleAI/statu…',
#                         'expanded_url': 'https://twitter.com/GoogleAI/status/1242149517274669057',
#                         'indices': ['23', '46'],
#                         'url': 'https://t.co/RzZk53QSBA'}],
#               'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '让我想起了影分身之术，不过那需要很多查克拉。 https://t.co/RzZk53QSBA',
#  'id': '1242288778657411072',
#  'id_str': '1242288778657411072',
#  'lang': 'zh',
#  'possibly_sensitive': False,
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Mon Mar 23 12:13:10 +0000 2020',
#  'display_text_range': ['0', '107'],
#  'entities': {'hashtags': [],
#               'media': [{'display_url': 'pic.twitter.com/DrJ5NXe4Pn',
#                          'expanded_url': 'https://twitter.com/yingshaoxo/status/1242061828630306816/photo/1',
#                          'id': '1242061814193475584',
#                          'id_str': '1242061814193475584',
#                          'indices': ['84', '107'],
#                          'media_url': 'http://pbs.twimg.com/media/ETywo6gUUAA1Z5F.jpg',
#                          'media_url_https': 'https://pbs.twimg.com/media/ETywo6gUUAA1Z5F.jpg',
#                          'sizes': {'large': {'h': '787',
#                                              'resize': 'fit',
#                                              'w': '1065'},
#                                    'medium': {'h': '787',
#                                               'resize': 'fit',
#                                               'w': '1065'},
#                                    'small': {'h': '502',
#                                              'resize': 'fit',
#                                              'w': '680'},
#                                    'thumb': {'h': '150',
#                                              'resize': 'crop',
#                                              'w': '150'}},
#                          'type': 'photo',
#                          'url': 'https://t.co/DrJ5NXe4Pn'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/DrJ5NXe4Pn',
#                                   'expanded_url': 'https://twitter.com/yingshaoxo/status/1242061828630306816/photo/1',
#                                   'id': '1242061814193475584',
#                                   'id_str': '1242061814193475584',
#                                   'indices': ['84', '107'],
#                                   'media_url': 'http://pbs.twimg.com/media/ETywo6gUUAA1Z5F.jpg',
#                                   'media_url_https': 'https://pbs.twimg.com/media/ETywo6gUUAA1Z5F.jpg',
#                                   'sizes': {'large': {'h': '787',
#                                                       'resize': 'fit',
#                                                       'w': '1065'},
#                                             'medium': {'h': '787',
#                                                        'resize': 'fit',
#                                                        'w': '1065'},
#                                             'small': {'h': '502',
#                                                       'resize': 'fit',
#                                                       'w': '680'},
#                                             'thumb': {'h': '150',
#                                                       'resize': 'crop',
#                                                       'w': '150'}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/DrJ5NXe4Pn'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': "It'll be enough for me if one day I could understand this kind "
#               'of knowledge easily. https://t.co/DrJ5NXe4Pn',
#  'id': '1242061828630306816',
#  'id_str': '1242061828630306816',
#  'lang': 'en',
#  'possibly_sensitive': False,
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Sat Mar 21 12:29:21 +0000 2020',
#  'display_text_range': ['0', '159'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'Even though thinking is a painful process, you must do it.\n'
#               '\n'
#               'By rethink your life, your goal, your reality, your strategy, '
#               'you will have a more clear way to go.',
#  'id': '1241341125111111682',
#  'id_str': '1241341125111111682',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Fri Mar 20 02:30:59 +0000 2020',
#  'display_text_range': ['0', '64'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '8149482',
#                                  'id_str': '8149482',
#                                  'indices': ['0', '11'],
#                                  'name': '美国之音中文网',
#                                  'screen_name': 'VOAChinese'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': "@VOAChinese No pain no gain, no down no rise, it's a good "
#               'thing.',
#  'id': '1240828150549864451',
#  'id_str': '1240828150549864451',
#  'in_reply_to_screen_name': 'VOAChinese',
#  'in_reply_to_status_id': '1240799975136620544',
#  'in_reply_to_status_id_str': '1240799975136620544',
#  'in_reply_to_user_id': '8149482',
#  'in_reply_to_user_id_str': '8149482',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Fri Mar 20 00:08:13 +0000 2020',
#  'display_text_range': ['0', '128'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '15804774',
#                                  'id_str': '15804774',
#                                  'indices': ['0', '11'],
#                                  'name': 'Guido van Rossum',
#                                  'screen_name': 'gvanrossum'},
#                                 {'id': '14749606',
#                                  'id_str': '14749606',
#                                  'indices': ['12', '20'],
#                                  'name': 'Dropbox',
#                                  'screen_name': 'Dropbox'}]},
#  'favorite_count': '2',
#  'favorited': False,
#  'full_text': '@gvanrossum @Dropbox So is that means Python is out of options? '
#               'Even though python got asyncio module for doing concurrent '
#               'work?',
#  'id': '1240792221764313089',
#  'id_str': '1240792221764313089',
#  'in_reply_to_screen_name': 'gvanrossum',
#  'in_reply_to_status_id': '1240764587965681664',
#  'in_reply_to_status_id_str': '1240764587965681664',
#  'in_reply_to_user_id': '15804774',
#  'in_reply_to_user_id_str': '15804774',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Thu Mar 19 21:18:00 +0000 2020',
#  'display_text_range': ['0', '21'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '732363',
#                                  'id_str': '732363',
#                                  'indices': ['0', '8'],
#                                  'name': 'Eric Xu, PhD 🧢🧢🧢',
#                                  'screen_name': 'mathena'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '@mathena Chinese WHO.',
#  'id': '1240749385849270272',
#  'id_str': '1240749385849270272',
#  'in_reply_to_screen_name': 'mathena',
#  'in_reply_to_status_id': '1240568274250678275',
#  'in_reply_to_status_id_str': '1240568274250678275',
#  'in_reply_to_user_id': '732363',
#  'in_reply_to_user_id_str': '732363',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Wed Mar 18 21:28:44 +0000 2020',
#  'display_text_range': ['0', '34'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/GoogleAI/statu…',
#                         'expanded_url': 'https://twitter.com/GoogleAI/status/1240331603282251776',
#                         'indices': ['11', '34'],
#                         'url': 'https://t.co/RJQNKCyi3I'}],
#               'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'Good work! https://t.co/RJQNKCyi3I',
#  'id': '1240389702211055616',
#  'id_str': '1240389702211055616',
#  'lang': 'en',
#  'possibly_sensitive': False,
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Wed Mar 18 06:27:30 +0000 2020',
#  'display_text_range': ['0', '185'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'Rationality of that experiment:\n'
#               '\n'
#               '1. Your boyfriend willing to do anything hard for you.\n'
#               '2. His body got exercised. More healthy.\n'
#               "3. The spirit of 'Never give up' works for every fields.",
#  'id': '1240162897180811264',
#  'id_str': '1240162897180811264',
#  'in_reply_to_screen_name': 'yingshaoxo',
#  'in_reply_to_status_id': '1240161501190582273',
#  'in_reply_to_status_id_str': '1240161501190582273',
#  'in_reply_to_user_id': '4512527954',
#  'in_reply_to_user_id_str': '4512527954',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Wed Mar 18 06:21:57 +0000 2020',
#  'display_text_range': ['0', '180'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'Let your boyfriend hang on at the horizontal bar. Then you hang '
#               'on upon your boyfriend. \n'
#               '\n'
#               'Can your boyfriend stay for 20 seconds? \n'
#               '\n'
#               "If so, please marry him. He's a reliable person.",
#  'id': '1240161501190582273',
#  'id_str': '1240161501190582273',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Wed Mar 18 04:08:10 +0000 2020',
#  'display_text_range': ['0', '128'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '46335511',
#                                  'id_str': '46335511',
#                                  'indices': ['0', '11'],
#                                  'name': 'Trevor Noah',
#                                  'screen_name': 'Trevornoah'},
#                                 {'id': '158414847',
#                                  'id_str': '158414847',
#                                  'indices': ['12', '25'],
#                                  'name': 'The Daily Show',
#                                  'screen_name': 'TheDailyShow'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': "@Trevornoah @TheDailyShow That's why I love America, they do "
#               'know how to respect others.\n'
#               '\n'
#               "Like, people don't wanna be disturbed.",
#  'id': '1240127832568795136',
#  'id_str': '1240127832568795136',
#  'in_reply_to_screen_name': 'Trevornoah',
#  'in_reply_to_status_id': '1239919483785031682',
#  'in_reply_to_status_id_str': '1239919483785031682',
#  'in_reply_to_user_id': '46335511',
#  'in_reply_to_user_id_str': '46335511',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Tue Mar 17 01:47:48 +0000 2020',
#  'display_text_range': ['0', '173'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/github/status/…',
#                         'expanded_url': 'https://twitter.com/github/status/1239597562614726656',
#                         'indices': ['150', '173'],
#                         'url': 'https://t.co/OjliCDaUTi'}],
#               'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': "I don't wanna see Microsoft became the only giant among the "
#               'Software World.\n'
#               '\n'
#               'For the dictatorship, somebody must do something, where are '
#               'you, Google? https://t.co/OjliCDaUTi',
#  'id': '1239730122057342977',
#  'id_str': '1239730122057342977',
#  'lang': 'en',
#  'possibly_sensitive': False,
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Mon Mar 16 00:40:02 +0000 2020',
#  'display_text_range': ['0', '105'],
#  'entities': {'hashtags': [],
#               'media': [{'display_url': 'pic.twitter.com/1dFDFP1hbi',
#                          'expanded_url': 'https://twitter.com/yingshaoxo/status/1239350676733517824/photo/1',
#                          'id': '1239350660929327108',
#                          'id_str': '1239350660929327108',
#                          'indices': ['82', '105'],
#                          'media_url': 'http://pbs.twimg.com/media/ETMO3BjWkAQsn5a.jpg',
#                          'media_url_https': 'https://pbs.twimg.com/media/ETMO3BjWkAQsn5a.jpg',
#                          'sizes': {'large': {'h': '757',
#                                              'resize': 'fit',
#                                              'w': '2048'},
#                                    'medium': {'h': '444',
#                                               'resize': 'fit',
#                                               'w': '1200'},
#                                    'small': {'h': '251',
#                                              'resize': 'fit',
#                                              'w': '680'},
#                                    'thumb': {'h': '150',
#                                              'resize': 'crop',
#                                              'w': '150'}},
#                          'type': 'photo',
#                          'url': 'https://t.co/1dFDFP1hbi'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/1dFDFP1hbi',
#                                   'expanded_url': 'https://twitter.com/yingshaoxo/status/1239350676733517824/photo/1',
#                                   'id': '1239350660929327108',
#                                   'id_str': '1239350660929327108',
#                                   'indices': ['82', '105'],
#                                   'media_url': 'http://pbs.twimg.com/media/ETMO3BjWkAQsn5a.jpg',
#                                   'media_url_https': 'https://pbs.twimg.com/media/ETMO3BjWkAQsn5a.jpg',
#                                   'sizes': {'large': {'h': '757',
#                                                       'resize': 'fit',
#                                                       'w': '2048'},
#                                             'medium': {'h': '444',
#                                                        'resize': 'fit',
#                                                        'w': '1200'},
#                                             'small': {'h': '251',
#                                                       'resize': 'fit',
#                                                       'w': '680'},
#                                             'thumb': {'h': '150',
#                                                       'resize': 'crop',
#                                                       'w': '150'}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/1dFDFP1hbi'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'We need a more powerful computer to achieve the ultimate '
#               'artificial intelligence. https://t.co/1dFDFP1hbi',
#  'id': '1239350676733517824',
#  'id_str': '1239350676733517824',
#  'lang': 'en',
#  'possibly_sensitive': False,
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Sat Mar 14 20:56:10 +0000 2020',
#  'display_text_range': ['0', '100'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'statworx.com/de/blog/using-…',
#                         'expanded_url': 'https://www.statworx.com/de/blog/using-reinforcement-learning-to-play-super-mario-bros-on-nes-using-tensorflow/',
#                         'indices': ['77', '100'],
#                         'url': 'https://t.co/6fnQOd9Eal'}],
#               'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': "It's weird to see others were able to get a good rl agent while "
#               "I couldn't.\n"
#               '\n'
#               'https://t.co/6fnQOd9Eal',
#  'id': '1238931954864701440',
#  'id_str': '1238931954864701440',
#  'lang': 'en',
#  'possibly_sensitive': False,
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web '
#            'App</a>',
#  'truncated': False}
#
#
# {'created_at': 'Fri Mar 13 07:10:55 +0000 2020',
#  'display_text_range': ['0', '101'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'towardsdatascience.com/computer-visio…',
#                         'expanded_url': 'https://towardsdatascience.com/computer-vision-for-tracking-8220759eee85',
#                         'indices': ['78', '101'],
#                         'url': 'https://t.co/7px7IJBk9E'}],
#               'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': "This is what I was looking for, I'll record a video tutorial "
#               'later at night:\n'
#               '\n'
#               'https://t.co/7px7IJBk9E',
#  'id': '1238361883666776064',
#  'id_str': '1238361883666776064',
#  'lang': 'en',
#  'possibly_sensitive': False,
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Tue Mar 10 00:25:56 +0000 2020',
#  'display_text_range': ['0', '113'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'The honor belongs to those great mathematicians. \n'
#               '\n'
#               'Just imagine a world without sum check algorithms like sha256.',
#  'id': '1237172804711141376',
#  'id_str': '1237172804711141376',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Sun Mar 08 20:30:52 +0000 2020',
#  'display_text_range': ['0', '159'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'Only in this way you can have a balanced life, work half, enjoy '
#               'half, and have a good sleep. \n'
#               '\n'
#               'Sleep well, play well, earn some money, what do you expect '
#               'more?',
#  'id': '1236751257366339586',
#  'id_str': '1236751257366339586',
#  'in_reply_to_screen_name': 'yingshaoxo',
#  'in_reply_to_status_id': '1236751227121209344',
#  'in_reply_to_status_id_str': '1236751227121209344',
#  'in_reply_to_user_id': '4512527954',
#  'in_reply_to_user_id_str': '4512527954',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Sun Mar 08 20:30:44 +0000 2020',
#  'display_text_range': ['0', '226'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'At the next morning, your work is basically complete, you can '
#               'then do some entertainment, watch novels, watch movies, and '
#               'even play games.  You do entertainment, they make noises, no '
#               'affects would be made between you and them.',
#  'id': '1236751227121209344',
#  'id_str': '1236751227121209344',
#  'in_reply_to_screen_name': 'yingshaoxo',
#  'in_reply_to_status_id': '1236751177011904513',
#  'in_reply_to_status_id_str': '1236751177011904513',
#  'in_reply_to_user_id': '4512527954',
#  'in_reply_to_user_id_str': '4512527954',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Sun Mar 08 20:30:32 +0000 2020',
#  'display_text_range': ['0', '271'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'Let me tell you when it is best to sleep in China: from 5pm to '
#               '1am.\n'
#               '\n'
#               'Because there is no important call during that time. It is also '
#               'a time when people are noisy.  When they are noisy, you put on '
#               'earplugs to go to sleep, when they are no longer noisy, you get '
#               'up to work.',
#  'id': '1236751177011904513',
#  'id_str': '1236751177011904513',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Sun Mar 08 20:30:04 +0000 2020',
#  'display_text_range': ['0', '54'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '这样你就可以有一半的时间工作，一半的时间娱乐，剩下的时间睡觉。睡得好，玩儿得好，挣得到钱，还有什么不满意的？',
#  'id': '1236751059353247746',
#  'id_str': '1236751059353247746',
#  'in_reply_to_screen_name': 'yingshaoxo',
#  'in_reply_to_status_id': '1236751005611630596',
#  'in_reply_to_status_id_str': '1236751005611630596',
#  'in_reply_to_user_id': '4512527954',
#  'in_reply_to_user_id_str': '4512527954',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Sun Mar 08 20:29:52 +0000 2020',
#  'display_text_range': ['0', '139'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '让我告诉你在中国什么时候睡觉最好：下午5点 -&gt; 第二天1点\n'
#               '\n'
#               '因为这段时间没有重要电话，同时也是人们比较吵的时间。他们吵，你戴上耳塞睡觉，他们不吵，你晚上起来工作。到第二天早上，你的工作基本上已经完成，你就可以娱乐了，看小说、看电影、甚至打游戏。你娱乐，他们吵，不影响。',
#  'id': '1236751005611630596',
#  'id_str': '1236751005611630596',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Sun Mar 08 01:04:30 +0000 2020',
#  'display_text_range': ['0', '86'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'Most people including me, nowadays, have a big problem: think '
#               'too many, did so little.',
#  'id': '1236457732363808768',
#  'id_str': '1236457732363808768',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Sat Mar 07 22:10:44 +0000 2020',
#  'display_text_range': ['0', '69'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '对于底层人民来讲，\n'
#               '你们每打一次游戏，都是在前往搬砖的道路上加一块砖\n'
#               '\n'
#               '对于有产的特权阶级而言，你们每打一次游戏都是在为缩小贫富差距做贡献',
#  'id': '1236414003745710081',
#  'id_str': '1236414003745710081',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Sat Mar 07 01:30:19 +0000 2020',
#  'display_text_range': ['0', '117'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/USACICI/status…',
#                         'expanded_url': 'https://twitter.com/USACICI/status/1236071272305524737',
#                         'indices': ['94', '117'],
#                         'url': 'https://t.co/m5qMnBiVS7'}],
#               'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'An 90+ years old American man made his own plane, and '
#               'successfully completed his flying test. https://t.co/m5qMnBiVS7',
#  'id': '1236101843492769792',
#  'id_str': '1236101843492769792',
#  'lang': 'en',
#  'possibly_sensitive': False,
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Thu Mar 05 19:19:21 +0000 2020',
#  'display_text_range': ['0', '208'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '8149482',
#                                  'id_str': '8149482',
#                                  'indices': ['0', '11'],
#                                  'name': '美国之音中文网',
#                                  'screen_name': 'VOAChinese'}]},
#  'favorite_count': '1',
#  'favorited': False,
#  'full_text': '@VOAChinese And another interesting fact is that 999‰ of '
#               "Chinese don't use any foreign countries app. \n"
#               '\n'
#               "So they won't worry about the spying on Chinese people. \n"
#               '\n'
#               "It's an unfair information war as I would say.",
#  'id': '1235646096925429762',
#  'id_str': '1235646096925429762',
#  'in_reply_to_screen_name': 'yingshaoxo',
# ...
#               'https://t.co/jp1WDgO0o2',
#  'id': '1183247362031882240',
#  'id_str': '1183247362031882240',
#  'lang': 'zh',
#  'possibly_sensitive': False,
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Sat Oct 12 07:09:52 +0000 2019',
#  'display_text_range': ['0', '180'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': "When I get a job, I'll send part of my money to those "
#               'developers I love. \n'
#               '\n'
#               'So they can continue to develop the open source repository that '
#               'I think may useful to change the society.',
#  'id': '1182916278018723841',
#  'id_str': '1182916278018723841',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Fri Oct 11 15:51:43 +0000 2019',
#  'display_text_range': ['0', '35'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '反思中国的教育\n\n躺在两个板凳之间\n\n恍恍惚惚脑袋里蹦出3个字：集中营',
#  'id': '1182685216378212353',
#  'id_str': '1182685216378212353',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Fri Oct 11 02:30:54 +0000 2019',
#  'display_text_range': ['0', '125'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'Although people stay awake 16 hours a day, the effective time '
#               'for brain work is only limited in two hours after a good sleep.',
#  'id': '1182483684449873920',
#  'id_str': '1182483684449873920',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Fri Oct 11 00:40:07 +0000 2019',
#  'display_text_range': ['0', '90'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '1401204486',
#                                  'id_str': '1401204486',
#                                  'indices': ['0', '8'],
#                                  'name': 'Harrison Kinsley🐍',
#                                  'screen_name': 'Sentdex'},
#                                 {'id': '1886909492',
#                                  'id_str': '1886909492',
#                                  'indices': ['9', '17'],
#                                  'name': 'OpenBCI',
#                                  'screen_name': 'OpenBCI'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '@Sentdex @OpenBCI From the first place, I think use our brain '
#               'to use vim to typing is cool',
#  'id': '1182455805376778240',
#  'id_str': '1182455805376778240',
#  'in_reply_to_screen_name': 'Sentdex',
#  'in_reply_to_status_id': '1182363832557166593',
#  'in_reply_to_status_id_str': '1182363832557166593',
#  'in_reply_to_user_id': '1401204486',
#  'in_reply_to_user_id_str': '1401204486',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Thu Oct 10 05:03:18 +0000 2019',
#  'display_text_range': ['0', '225'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': 'We live in a chaotic world, with false information and false '
#               'principles flying all over the sky.\n'
#               '\n'
#               ' Only scattered, fools like me are willing to share the right '
#               'information.\n'
#               '\n'
#               '我们生活在一个混乱的世界，虚假信息和错误原则满天飞。\n'
#               '\n'
#               '只有零散的，像我一样的傻子愿意共享正确的信息。',
#  'id': '1182159649295831040',
#  'id_str': '1182159649295831040',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Tue Oct 08 09:44:10 +0000 2019',
#  'display_text_range': ['0', '35'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '467193856',
#                                  'id_str': '467193856',
#                                  'indices': ['0', '6'],
#                                  'name': 'rhso',
#                                  'screen_name': 'rhsor'},
#                                 {'id': '232201624',
#                                  'id_str': '232201624',
#                                  'indices': ['7', '18'],
#                                  'name': '方舟子',
#                                  'screen_name': 'fangshimin'}]},
#  'favorite_count': '3',
#  'favorited': False,
#  'full_text': '@rhsor @fangshimin 莫雷应该会发：我支持黑人争取自由',
#  'id': '1181505555065520128',
#  'id_str': '1181505555065520128',
#  'in_reply_to_screen_name': 'rhsor',
#  'in_reply_to_status_id': '1181428856928030722',
#  'in_reply_to_status_id_str': '1181428856928030722',
#  'in_reply_to_user_id': '467193856',
#  'in_reply_to_user_id_str': '467193856',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Tue Oct 08 03:56:31 +0000 2019',
#  'display_text_range': ['0', '22'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '130429681',
#                                  'id_str': '130429681',
#                                  'indices': ['0', '6'],
#                                  'name': 'Hao Chen',
#                                  'screen_name': 'haoel'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '@haoel Go 的官网不是一直打不开吗？',
#  'id': '1181418068859211776',
#  'id_str': '1181418068859211776',
#  'in_reply_to_screen_name': 'haoel',
#  'in_reply_to_status_id': '1181413054229049345',
#  'in_reply_to_status_id_str': '1181413054229049345',
#  'in_reply_to_user_id': '130429681',
#  'in_reply_to_user_id_str': '130429681',
#  'lang': 'zh',
#  'retweet_count': '1',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Tue Oct 08 03:55:30 +0000 2019',
#  'display_text_range': ['0', '37'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '650013',
#                                  'id_str': '650013',
#                                  'indices': ['0', '9'],
#                                  'name': 'bradfitz',
#                                  'screen_name': 'bradfitz'}]},
#  'favorite_count': '11',
#  'favorited': False,
#  'full_text': '@bradfitz Stay with Hong Kong people!',
#  'id': '1181417812721467394',
#  'id_str': '1181417812721467394',
#  'in_reply_to_screen_name': 'bradfitz',
#  'in_reply_to_status_id': '1181312535326162944',
#  'in_reply_to_status_id_str': '1181312535326162944',
#  'in_reply_to_user_id': '650013',
#  'in_reply_to_user_id_str': '650013',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Tue Oct 08 02:06:34 +0000 2019',
#  'display_text_range': ['0', '73'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '我这辈子比较讨厌的事就是上学：在学校课堂里整日的浪费时间和生命。\n'
#               '\n'
#               '(听 classmates and teacher talking shit)',
#  'id': '1181390395638337536',
#  'id_str': '1181390395638337536',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Tue Oct 08 00:07:51 +0000 2019',
#  'display_text_range': ['0', '105'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '15745368',
#                                  'id_str': '15745368',
#                                  'indices': ['0', '11'],
#                                  'name': 'Marco Rubio',
#                                  'screen_name': 'marcorubio'},
#                                 {'id': '19923144',
#                                  'id_str': '19923144',
#                                  'indices': ['12', '16'],
#                                  'name': 'NBA',
#                                  'screen_name': 'NBA'},
#                                 {'id': '19077044',
#                                  'id_str': '19077044',
#                                  'indices': ['17', '32'],
#                                  'name': 'Houston Rockets',
#                                  'screen_name': 'HoustonRockets'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '@marcorubio @NBA @HoustonRockets They should protect the '
#               'freedom of speech. Especially for the Americans.',
#  'id': '1181360522240745472',
#  'id_str': '1181360522240745472',
#  'in_reply_to_screen_name': 'marcorubio',
#  'in_reply_to_status_id': '1181173981422014464',
#  'in_reply_to_status_id_str': '1181173981422014464',
#  'in_reply_to_user_id': '15745368',
#  'in_reply_to_user_id_str': '15745368',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Tue Oct 08 00:04:08 +0000 2019',
#  'display_text_range': ['0', '54'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '8149482',
#                                  'id_str': '8149482',
#                                  'indices': ['0', '11'],
#                                  'name': '美国之音中文网',
#                                  'screen_name': 'VOAChinese'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '@VOAChinese They should protect the freedom of speech.',
#  'id': '1181359586806095872',
#  'id_str': '1181359586806095872',
#  'in_reply_to_screen_name': 'VOAChinese',
#  'in_reply_to_status_id': '1181288971537543169',
#  'in_reply_to_status_id_str': '1181288971537543169',
#  'in_reply_to_user_id': '8149482',
#  'in_reply_to_user_id_str': '8149482',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Mon Oct 07 16:03:45 +0000 2019',
#  'display_text_range': ['0', '37'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '732363',
#                                  'id_str': '732363',
#                                  'indices': ['0', '8'],
#                                  'name': 'Eric Xu, PhD 🧢🧢🧢',
#                                  'screen_name': 'mathena'},
#                                 {'id': '22491223',
#                                  'id_str': '22491223',
#                                  'indices': ['9', '18'],
#                                  'name': '肥宅海牛猪',
#                                  'screen_name': 'mrseacow'}]},
#  'favorite_count': '1',
#  'favorited': False,
#  'full_text': '@mathena @mrseacow 想起了一句话：留美是生活，反美是工作',
#  'id': '1181238692523851776',
#  'id_str': '1181238692523851776',
#  'in_reply_to_screen_name': 'mathena',
#  'in_reply_to_status_id': '1181234184930512902',
#  'in_reply_to_status_id_str': '1181234184930512902',
#  'in_reply_to_user_id': '732363',
#  'in_reply_to_user_id_str': '732363',
#  'lang': 'zh',
#  'retweet_count': '2',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Mon Oct 07 16:00:42 +0000 2019',
#  'display_text_range': ['0', '19'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '130429681',
#                                  'id_str': '130429681',
#                                  'indices': ['0', '6'],
#                                  'name': 'Hao Chen',
#                                  'screen_name': 'haoel'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '@haoel 批评什么，什么就是好东西',
#  'id': '1181237924156735488',
#  'id_str': '1181237924156735488',
#  'in_reply_to_screen_name': 'haoel',
#  'in_reply_to_status_id': '1181058048879513600',
#  'in_reply_to_status_id_str': '1181058048879513600',
#  'in_reply_to_user_id': '130429681',
#  'in_reply_to_user_id_str': '130429681',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Sat Oct 05 23:31:01 +0000 2019',
#  'display_text_range': ['0', '144'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '不喜欢中国女生的很大一个原因是： 做个爱还喜欢走那么多过场\n'
#               '\n'
#               '为什么要先唱首含蓄隐晦的情歌，再陪你逛街，再陪你喝奶茶，再陪你吃饭，再陪你看电影，才能进入正题\n'
#               '\n'
#               '难道从第一眼看到我，你都不想 fuck me? 那凭什么说你愿意和我在一起？你根本就是不喜欢我\n'
#               '\n'
#               '还是美国电影里的爱情观最有效率',
#  'id': '1180626475516514305',
#  'id_str': '1180626475516514305',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Thu Oct 03 23:04:53 +0000 2019',
#  'display_text_range': ['0', '22'],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': '8149482',
#                                  'id_str': '8149482',
#                                  'indices': ['0', '11'],
#                                  'name': '美国之音中文网',
#                                  'screen_name': 'VOAChinese'}]},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': '@VOAChinese 看起来就不是好东西。',
#  'id': '1179895123506683904',
#  'id_str': '1179895123506683904',
#  'in_reply_to_screen_name': 'VOAChinese',
#  'in_reply_to_status_id': '1179536679159250944',
#  'in_reply_to_status_id_str': '1179536679159250944',
#  'in_reply_to_user_id': '8149482',
#  'in_reply_to_user_id_str': '8149482',
#  'lang': 'zh',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}
#
#
# {'created_at': 'Thu Oct 03 18:20:10 +0000 2019',
#  'display_text_range': ['0', '243'],
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': '0',
#  'favorited': False,
#  'full_text': "The good part about being alone is that you don't have to be "
#               'slaves anymore.\n'
#               '\n'
#               'You can have full control over your happiness.\n'
#               '\n'
#               'You can decide when you start to work, when to eat, and when to '
#               'sleep. No one would stop you from your natural needs.',
#  'id': '1179823473285193728',
#  'id_str': '1179823473285193728',
#  'lang': 'en',
#  'retweet_count': '0',
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False}

# %%
main_dict = {}
date_list = []

for tweet in data:
    tweet = tweet['tweet']
    id = tweet["id_str"]
    date = str(parse(tweet['created_at'])).split("+")[0]
    text = tweet["full_text"]
    if "in_reply_to_status_id_str" not in tweet:
        a_tweet_dict = {
            "date": date,
            "text": text,
        }
        main_dict.update({id: a_tweet_dict})
        date_list.append(date)

for tweet in data:
    tweet = tweet['tweet']
    id = tweet["id_str"]
    date = str(parse(tweet['created_at'])).split("+")[0]
    text = tweet["full_text"]
    if "in_reply_to_status_id_str" in tweet:
        reply_id = tweet["in_reply_to_status_id_str"]
        if reply_id in main_dict.keys():
            main_dict[reply_id]['text'] += "\n\n\n\n" + text
        else:
            pass
        
main_list = list(main_dict.values())

# take second element for sort
def return_date(elem):
    return elem["date"]

# sort list with key
main_list.sort(key=return_date)

pprint(main_list[:10])
# Out:
# [{'date': '2015-12-10 01:13:44', 'text': 'https://t.co/Nx6tOXQpub'},
#  {'date': '2017-03-05 06:54:06',
#   'text': 'I just deployed a high performance cloud server on '
#           "https://t.co/d8GymeVCoH ! It's cheaper anyway!\n"
#           '#ILoveVultr #Cloud https://t.co/5IJXDNu0cR'},
#  {'date': '2017-04-10 19:53:34', 'text': '我决定转战Twitter！'},
#  {'date': '2017-04-10 21:27:49',
#   'text': 'China local government powered by houses.'},
#  {'date': '2017-04-11 12:37:47', 'text': 'Oh my god! \n\n看不懂Twitter上这帮人在说什么…'},
#  {'date': '2017-04-11 17:59:30', 'text': 'I got lost in front of GaoKao.'},
#  {'date': '2017-04-11 18:10:46',
#   'text': '同样是言论，自己做个blog和用Twitter有什么区别\n'
#           '\n'
#           '感觉都差不多啊，我为什么要执着于自己做一个…\n'
#           '\n'
#           '还有视频、音频的上传下载\n'
#           '\n'
#           '都有现成的，我为什么想自己做一个？'},
#  {'date': '2017-04-11 21:22:02', 'text': '即使有2682惨案，也不能阻止我对远方的向往。'},
#  {'date': '2017-04-12 03:10:17',
#   'text': 'RT @dbader_org: "Talk is cheap. Show me the code." – Linus '
#           'Torvalds'},
#  {'date': '2017-04-12 12:31:24', 'text': '几十年前考不上大学就只能种地，现在至少可以经商和写代码。'}]

# %%
for oneday in main_list[-5:]:
    date = oneday["date"]
    text = oneday["text"]
    print(text)
    print("\n\n----------------\n\n")
# Out:
# You success level depends on how much pleasures that you can give to others.
#
# Like Twitter, YouTube, Telegram, they gave me pleasures, so they are success.
#
# 你的成功取决于你取悦别人的水平。
#
# 感觉有点道理啊，因为一个好的服务就是要让人感到愉悦，比如 Twitter, YouTube, Telegram.
#
#
#
# 与效率说不矛盾，减少重复劳动，有更多时间享受生活，that's a pleasure.
#
# This has no combat with the efficiency theory, because when you are efficiency, you do less repeated work. Then with the time you've saved, you can enjoy your life more.
#
#
# ----------------
#
#
# 我们可以做游戏，可以做网页，可以做用 IDE 做 Native App，但这些东西是个人都可以做。
# 所以我不想做。
#
# We could make games, we could make websites, we could make Native Apps by using specific IDE.
# But I don't wanna do that because everyone could do that.
#
#
# ----------------
#
#
# 我享受一个人的生活。
#
# 记得初中时班主任问我这辈子最想干什么，我说我想当鲁宾逊。她当时以为我疯了(有精神病)。
#
# 实际上，就目前来讲，如果鲁宾逊独自拥有一个小岛，一间自制别墅，一台可以上网的电脑。不知道他可以过得多么舒适！
#
#
# ----------------
#
#
# Next time if I do freelance again, I'll make a contract.
#
# https://t.co/UIvBXEHNkl
#
#
# ----------------
#
#
# It makes me doubt weather the GitHub is still a trustable platform for private repository. #Github https://t.co/J78RtD5iaD
#
#
# ----------------

# %%
# !rm tweets.db
# Out:
# rm: cannot remove 'tweets.db': No such file or directory

# %%
import os
import sqlite3

class Self():
    _root_path = "."
    pass

self = Self()
self.SQL_DATA_FILE = os.path.join(self._root_path, "tweets.db")
if not os.path.exists(self.SQL_DATA_FILE):
    print(f"SQL doesn't exist: {self.SQL_DATA_FILE}")
    print(f"We'll create a new one!")
self._sql_conn = sqlite3.connect(self.SQL_DATA_FILE, check_same_thread=False)
self._sql_cursor = self._sql_conn.cursor()
self._sql_cursor.execute('''CREATE TABLE IF NOT EXISTS thoughts
            (date TEXT, type TEXT, text TEXT, images TEXT)''')

for oneday in main_list[-5:]:
    date = oneday["date"]
    text = oneday["text"]
    day = (date, "twitter", text, json.dumps([]))
    self._sql_cursor.execute("INSERT INTO thoughts VALUES (?,?,?,?)", day)
    self._sql_conn.commit()
# Out:
# SQL doesn't exist: ./tweets.db
# We'll create a new one!
